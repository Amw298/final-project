# %% [markdown]
# Richard Conrad
#
# SubMetric: Housing price and value. Description: Shows the median price of housing in each neighborhood to see what the cheapest neighborhoods are for purchasing a house. This is a metric that will greatly impact how accesible it is for a person to purchase their own property.

# %%
import pandas as pd
hv = pd.read_csv("Housing.csv")
hve = hv.iloc[:,[0,21,23]]
hve
# Out:
#            Neighborhood  Median Home  Value (2010)  Median Sale Price (2010)
# 0      Allegheny Center                   136300.0                       NaN
# 1        Allegheny West                   123600.0                  309940.0
# 2             Allentown                    42200.0                    8500.0
# 3             Arlington                    44200.0                   15397.0
# 4     Arlington Heights                    64400.0                       NaN
# ..                  ...                        ...                       ...
# 85  Upper Lawrenceville                    48700.0                   38000.0
# 86             West End                    29800.0                   14383.0
# 87         West Oakland                    61100.0                   66000.0
# 88             Westwood                    93700.0                   70000.0
# 89              Windgap                    78200.0                   59950.0
#
# [90 rows x 3 columns]

# %%
hve.plot.bar(x='Neighborhood')
