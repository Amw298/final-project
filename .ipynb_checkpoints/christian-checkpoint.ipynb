# %% [markdown]
# Christian Waronsky
#
# Submetric: Price inspections of local gas, grocery scale, etc.
# Description: Essentially, this shows whether or not customers are being charged as advertised. I will analyze this to show which neighborhoods may be suseptible to unfair pricing.

# %%
import pandas as pd 

priceIns = pd.read_csv("PriceInspections.csv")

i = 0

pghData = priceIns.loc[priceIns['mailing_city'] == 'PITTSBURGH']


for row in pghData.index:
    print(pghData.iloc[:,3])
    
#print(pghData.iloc[])
# Out:
# 7       PITTSBURGH
# 8       PITTSBURGH
# 31      PITTSBURGH
# 32      PITTSBURGH
# 72      PITTSBURGH
#            ...
# 3161    PITTSBURGH
# 3163    PITTSBURGH
# 3165    PITTSBURGH
# 3167    PITTSBURGH
# 3168    PITTSBURGH
# Name: mailing_city, Length: 1849, dtype: object
# 7       PITTSBURGH
# 8       PITTSBURGH
# 31      PITTSBURGH
# 32      PITTSBURGH
# 72      PITTSBURGH
#            ...
# 3161    PITTSBURGH
# 3163    PITTSBURGH
# 3165    PITTSBURGH
# 3167    PITTSBURGH
# 3168    PITTSBURGH
# Name: mailing_city, Length: 1849, dtype: object
# 7       PITTSBURGH
# 8       PITTSBURGH
# 31      PITTSBURGH
# 32      PITTSBURGH
# 72      PITTSBURGH
#            ...
# 3161    PITTSBURGH
# 3163    PITTSBURGH
# 3165    PITTSBURGH
# 3167    PITTSBURGH
# 3168    PITTSBURGH
# Name: mailing_city, Length: 1849, dtype: object
# 7       PITTSBURGH
# 8       PITTSBURGH
# 31      PITTSBURGH
# 32      PITTSBURGH
# 72      PITTSBURGH
#            ...
# 3161    PITTSBURGH
# 3163    PITTSBURGH
# ...

# %% [markdown]
# NOTE: This is very temporary. I am still working out the best way to plot the data.
