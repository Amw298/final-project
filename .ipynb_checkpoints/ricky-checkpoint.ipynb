# %% [markdown]
# Richard Conrad
#
# SubMetric: Housing price and value. Description: Shows the median price of housing in each neighborhood to see what the cheapest neighborhoods are for purchasing a house. This is a metric that will greatly impact how accesible it is for a person to purchase their own property.

# %%
import pandas as pd
hv = pd.read_csv("Housing.csv")
hv = hv.sort_values('Median Home Value', ascending = False)
hve =hv.iloc[:,[0,21]]
hve = hve.dropna()
hve = hve = hve.reset_index(drop=True)

hve.head(15)
# Out:
#                  Neighborhood  Median Home Value
# 0         Squirrel Hill North           344900.0
# 1               North Oakland           273000.0
# 2                   Shadyside           264860.0
# 3                Point Breeze           240300.0
# 4         Squirrel Hill South           201400.0
# 5               Regent Square           196300.0
# 6               Highland Park           167400.0
# 7                  Friendship           167300.0
# 8              Strip District           161800.0
# 9            South Side Flats           153750.0
# 10            Central Oakland           144350.0
# 11           Allegheny Center           136300.0
# 12  Central Business District           125800.0
# 13          Central Northside           124300.0
# 14             Allegheny West           123600.0

# %%
hve.plot.bar(x='Neighborhood',figsize=(15,3))
# Out:
#            Neighborhood  Median Home Value
# 75  Squirrel Hill North           344900.0
# 55        North Oakland           273000.0
# 67            Shadyside           264860.0
# 62         Point Breeze           240300.0
# 76  Squirrel Hill South           201400.0
# 65        Regent Square           196300.0
# 39        Highland Park           167400.0
# 33           Friendship           167300.0

# %% [markdown]
# Conclusion: Squirrel Hill
# =
# According to the data, the neighborhood in Pittsburgh in terms of average household income. We must remember and consider, however, that this data is not all encompassing due to the relatively low and inconsistent sample size. It was updated last in 2015, so there is a chance for change, especially when considering the drastic change in political climate in years since. Nonetheless, average household income doesn't change as drastically and, thus, this data still gives us a general idea of what neighborhood is best for high household income.
